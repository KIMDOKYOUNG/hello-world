# %%
import os
import sys
import pandas as pd
import requests
import re
from datetime import datetime
from bs4 import BeautifulSoup
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
import time

# %%
browser = Chrome()
delay = 3
base_url = 'https://cafe.naver.com/deadodanggu'

# %%
browser.get(base_url)
browser.implicitly_wait(delay)

# %%
browser.find_element_by_css_selector('span.gnb_txt').click()
browser.implicitly_wait(delay)

# %% [markdown]
# ## 네이버 로그인 보안 강화로 코드로 접속 불가, 직접 쳐야한다.
# #### browser.find_element_by_name('id').send_keys(naver_id)
# #### browser.find_element_by_name('pw').send_keys(naver_pw)
# #### browser.find_element_by_css_selector('input.btn_global').send_keys(Keys.ENTER)

# %%
cafe_menu = browser.find_element_by_css_selector('div#cafe-menu')
browser.implicitly_wait(delay)

# %%
menu_list = cafe_menu.find_elements_by_tag_name('a')

# %%
menu_source = pd.DataFrame({'name' : [], 'source' : []})
name = []
source = []

for menu in menu_list :
    menu_name = menu.text
    if '전체글' in menu_name : # 원하는 검색어를 집어넣어야 한다.
        insert_menu = pd.DataFrame({'name' : [menu_name], 'source' : [menu]})
        menu_source = menu_source.append(insert_menu)

# %%
menu_source.index = range(len(menu_source))

# %%
menu_source
# Out:
#     name                                             source
# 0  전체글보기  <selenium.webdriver.remote.webelement.WebEleme...

# %%
# 원하는 카테고리 클릭을 위해서 인덱싱을 진행하는데, 앞에부분만 바꾸면된다.
menu_source.iloc[0,1].send_keys(Keys.ENTER)
                                            
browser.implicitly_wait(delay)

# %%
i = 1
post_list = pd.DataFrame({'name' : [],
                         'user' : [],
                         'time' : [],
                         'link' : []})
while True : #총페이지 수를 가늠하기 힘들기 때문에 무한 반복 루프 사용
    try :
        browser.switch_to_frame(browser.find_element_by_name('cafe_main'))
        page = browser.find_element_by_css_selector('div.prev-next')
        page_num = page.find_elements_by_tag_name('a')
    except :
        page = browser.find_element_by_css_selector('div.prev-next')
        page_num = page.find_elements_by_tag_name('a')        
    
    for num in range(len(page_num)) :           
            try :  
                browser.switch_to_frame(browser.find_element_by_name('cafe_main'))
                page = browser.find_element_by_css_selector('div.prev-next')
                page_num = page.find_elements_by_tag_name('a')
                if '다음' in page_num[num].text :
                    page_num[num].send_keys(Keys.ENTER)
                    break
                elif '이전' in page_num[num].text :
                    pass
                else :
                    page_num[num].send_keys(Keys.ENTER)
            except :
                page = browser.find_element_by_css_selector('div.prev-next')
                page_num = page.find_elements_by_tag_name('a')
                if '다음' in page_num[num].text :
                    page_num[num].send_keys(Keys.ENTER)
                    break        
                elif '이전' in page_num[num].text :
                    pass
                else :
                    page_num[num].send_keys(Keys.ENTER)
                
            source = browser.page_source
            html = BeautifulSoup(source, 'html.parser')
            tbody = html.find_all('div', {'class' : 'article-board m-tcol-c'})
            post_name = tbody[1].find_all('a', {'class' :'article'})
            post_user = tbody[1].find_all('a', {'class' : 'm-tcol-c'})
            post_time = tbody[1].find_all('td', {'class' : 'td_date'})

            name = []
            user = []
            time = []
            link = []

            for n in post_name :
                n = n.text.replace('\n','')
                name.append(re.sub(r' {2,}' , ' ', n))
                
            for u in post_user :
                user.append(u.text)

            for t in post_time :
                time.append(re.sub('[^0-9\.\:]', '', t.text))
                
            for l in range(len(post_name)) :
                post_link = base_url + post_name[l]['href']
                link.append(post_link)

            posting = pd.DataFrame({'name' : name,
                                    'user' : user,
                                    'time' : time,
                                   'link' : link})

            post_list = post_list.append(posting)

    if len(page_num) < 11 :
        break
    
post_list = post_list.drop_duplicates(subset='name', keep='last')
post_list.index = range(len(post_list))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DeprecationWarning: use driver.switch_to.frame instead
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-27-da08e08204f1> in <module>()
#      16             try :
# ---> 17                 browser.switch_to_frame(browser.find_element_by_name('cafe_main'))
#      18                 page = browser.find_element_by_css_selector('div.prev-next')
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_name(self, name)
#     495         """
# --> 496         return self.find_element(by=By.NAME, value=name)
#     497
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"name","selector":"cafe_main"}
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)
#
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-da08e08204f1> in <module>()
#      28                 page = browser.find_element_by_css_selector('div.prev-next')
#      29                 page_num = page.find_elements_by_tag_name('a')
# ---> 30                 if '다음' in page_num[num].text :
#      31                     page_num[num].send_keys(Keys.ENTER)
#      32                     break
#
# IndexError: list index out of range

# %%
post_list = post_list.drop_duplicates(subset='name', keep='last')
post_list.index = range(len(post_list))

post_list
# Out:
#                                                    name     user         time  \
# 0                         (봄 여성 블라우스 원피스 티셔츠 300장 땡처리)        얍비  2019.01.14.
# 1                                          봄,가을 상의 땡처리       모두스  2019.01.14.
# 2                                        더 늦기전에 시작해보세요     들꽃맘77  2019.01.14.
# 3      수출을 원하시면 수출 국내판매 불가하시면 불가 재고의 격을 한층 높여주는 도깨비 ...   도깨비이두표  2019.01.14.
# 4      재고매입전문 더미더미 입니다 의류재고 매장재고 폐업재고 동대문재고 브랜드재고 이월...    더미 더미  2019.01.13.
# 5                                             등업신청드립니다        산칸  2019.01.13.
# 6      SNS, 폐쇄몰, 공동구매등에서 항상 잘 나가는 홈쇼핑 의류 및 잡화들 지속적으로...    DS아울렛  2019.01.13.
# 7        매입전문 더미더미 입니다 재고의류 재고잡화 이월상품 물류재고 폐업진행 매장재고 등     더미 더미  2019.01.12.
# 8                                중고 남.여 옷걸이 팝니다 ( 네파 )    하모니카12  2019.01.12.
# 9                                     커피 한잔값으로 도전해보세요~     들꽃맘77  2019.01.12.
# 10     각종 재고 의류,구두,가방,잡화,창고정리.정직하게 모든상품 무조건 삽니다)   (...      베스트  2019.01.12.
# 11     이월겨울아동복 3000원~땡아님! ~ (3배마진 완판 퀄)~ 500장이상~장사 대...  에리카5382  2019.01.12.
# 12                                       한번 읽고 도전해보세요~     들꽃맘77  2019.01.11.
# 13                            C319_아동 라쿤 오리털 패딩-천여장 덤핑      BM의류  2019.01.11.
# 14                             C318_남녀공용 빅사이즈 폴라폴리스 조끼      BM의류  2019.01.11.
# 15     매입전문 더미더미 입니다 생활잡화 재고의류 잡화재고 땡처리 덤핑정리 물류창고정리 ...    더미 더미  2019.01.11.
# 16     찾아주셔도 불러주셔도 도깨비 이두표는 감사할 뿐이랍니다 010 2239 5627 ...   도깨비이두표  2019.01.11.
# 17                                            주니어 원피스티    Byjjoo  2019.01.11.
# 18                                          무지투피스 7부소매    Byjjoo  2019.01.11.
# 19         C317_아직 겨울은 끝나지 않았어요~! 넘나 예쁜 광폭 목도리 구경하세요^^      BM의류  2019.01.10.
# 20           C316_다양한 여성 팬츠류- 사이즈 좋아요 [파격 땡처리 30장+서비스]      BM의류  2019.01.10.
# 21                      C315_밍크 수면원피스+수면 상하의 세트 소량 땡처리      BM의류  2019.01.10.
# 22                         zz1144 라운드 니트 2종 완사시 1,500원   현민유통김이사  2019.01.10.
# 23                             zz1145 지퍼레깅스 완사시 1,000원   현민유통김이사  2019.01.10.
# 24                                          한번 시작하보세요~     들꽃맘77  2019.01.10.
# 25     매입전문 더미더미 입니다 각종재고 의류땡 재고땡처리 매장재고 폐업진행 물류재고 창...    더미 더미  2019.01.10.
# 26                  (판매완료)_(브랜드 래시가드 12000장 땡처리) 연예인모델        얍비  2019.01.10.
# 27                                         어린이 겨울잠바,쪼끼       모두스  2019.01.10.
# 28                                 공홈에서 판매중인 압박스타킹 땡처리    브루스리80  2019.01.10.
# 29                             GET USED 여성 인조무스탕 코트 만원    브루스리80  2019.01.10.
# ...                                                 ...      ...          ...
# 8759                                   아둥가모자외 기타모자 땡처리       모두스  2019.01.15.
# 8760                                    매입 꼭 여기 전화 해야해      여성의류  2019.01.15.
# 8761                         아동 신발 1250족 1800원 땡처리합니다.      테라유통  2019.01.15.
# 8762                   야광봉 응원봉 땡처리 개당 30원, 20만여개(내용참조)      창100  2019.01.15.
# 8763                                        방금 가입 했어요.     왕눈깔사탕  2019.01.15.
# 8764                                               꾼소리     왕눈깔사탕  2019.01.15.
# 8765                                                출첵     왕눈깔사탕  2019.01.15.
# 8766                                    안녕하세요. 반가워요 ^^     왕눈깔사탕  2019.01.15.
# 8767                                               출석!   ㅇ일체유심조ㅇ  2019.01.15.
# 8768                                     지금이라도 시작해보세요~     들꽃맘77  2019.01.15.
# 8769                            신상품 스카프 다양한 패턴들 판매합니다.      NEXT  2019.01.15.
# 8770               D.V 스왈로브스키 에디션 LED 크리스털 마사지기 판매합니다.      NEXT  2019.01.15.
# 8771                    LG화장품 스킨케어,에멀전 외 다양한 제품 판매합니다.      NEXT  2019.01.15.
# 8772        이런재고 저런재고 각종재고 사고 팝니다 010 2239 5627 도깨비이두표    도깨비이두표  2019.01.15.
# 8773           대용량청소기 베스테프레미엄업소용 가정용 SVC-K250Y 2018신제품        새영  2019.01.15.
# 8774                                   GET USED 여성 무스탕     드렁큰나비  2019.01.15.
# 8775                                  패딩 2컬러 3사이즈 팔아요~     라이딩 김  2019.01.15.
# 8776                                              출첵!!     라이딩 김  2019.01.15.
# 8777                                               장사꾼     라이딩 김  2019.01.15.
# 8778                                           안녕하세요^^     라이딩 김  2019.01.15.
# 8779                                         남자바지판매합니다        내거  2019.01.14.
# 8780                                          모자 판매합니다     내일을위해  2019.01.14.
# 8781                          원단 포인트 집게핀 도매(악세사리 도매전문)     Jm쥬얼리  2019.01.14.
# 8782                                         바람막이 이중점퍼       모두스  2019.01.14.
# 8783                     ★ 재고 삽니다 ~ 매장집기및.의류.신발.가방 .잡화        인지  2019.01.14.
# 8784   각종 재고 덤핑 의류 신발 잡화 아동복 가방 매입합니다.땡심이 010-7667-4...      땡심이  2019.01.14.
# 8785                                    미니 나노블럭 300개 땡    하모니카12  2019.01.14.
# 8786                       핸드메이드 코트 울100% 막스패턴 공급해드립니다        싸유  2019.01.14.
# 8787                        (봄여름 여성 미시의류 상의 1500장 떙처리)        얍비  2019.01.14.
# 8788                                               스키장        얍비  2019.01.14.
#
#                                                    link
# 0     https://cafe.naver.com/deadodanggu/ArticleRead...
# 1     https://cafe.naver.com/deadodanggu/ArticleRead...
# 2     https://cafe.naver.com/deadodanggu/ArticleRead...
# 3     https://cafe.naver.com/deadodanggu/ArticleRead...
# 4     https://cafe.naver.com/deadodanggu/ArticleRead...
# 5     https://cafe.naver.com/deadodanggu/ArticleRead...
# 6     https://cafe.naver.com/deadodanggu/ArticleRead...
# 7     https://cafe.naver.com/deadodanggu/ArticleRead...
# 8     https://cafe.naver.com/deadodanggu/ArticleRead...
# 9     https://cafe.naver.com/deadodanggu/ArticleRead...
# 10    https://cafe.naver.com/deadodanggu/ArticleRead...
# 11    https://cafe.naver.com/deadodanggu/ArticleRead...
# 12    https://cafe.naver.com/deadodanggu/ArticleRead...
# 13    https://cafe.naver.com/deadodanggu/ArticleRead...
# 14    https://cafe.naver.com/deadodanggu/ArticleRead...
# 15    https://cafe.naver.com/deadodanggu/ArticleRead...
# 16    https://cafe.naver.com/deadodanggu/ArticleRead...
# 17    https://cafe.naver.com/deadodanggu/ArticleRead...
# 18    https://cafe.naver.com/deadodanggu/ArticleRead...
# 19    https://cafe.naver.com/deadodanggu/ArticleRead...
# 20    https://cafe.naver.com/deadodanggu/ArticleRead...
# 21    https://cafe.naver.com/deadodanggu/ArticleRead...
# 22    https://cafe.naver.com/deadodanggu/ArticleRead...
# 23    https://cafe.naver.com/deadodanggu/ArticleRead...
# 24    https://cafe.naver.com/deadodanggu/ArticleRead...
# 25    https://cafe.naver.com/deadodanggu/ArticleRead...
# 26    https://cafe.naver.com/deadodanggu/ArticleRead...
# 27    https://cafe.naver.com/deadodanggu/ArticleRead...
# 28    https://cafe.naver.com/deadodanggu/ArticleRead...
# 29    https://cafe.naver.com/deadodanggu/ArticleRead...
# ...                                                 ...
# 8759  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8760  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8761  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8762  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8763  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8764  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8765  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8766  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8767  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8768  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8769  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8770  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8771  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8772  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8773  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8774  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8775  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8776  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8777  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8778  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8779  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8780  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8781  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8782  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8783  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8784  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8785  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8786  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8787  https://cafe.naver.com/deadodanggu/ArticleRead...
# 8788  https://cafe.naver.com/deadodanggu/ArticleRead...
#
# [8789 rows x 4 columns]

# %%
post_list.to_csv(os.getcwd() + "/" + "cafe_deadodanggu" + ".csv", mode = 'w', header = True, index = None, encoding = 'utf-8-sig')

# %%
post_list['user'].value_counts()
# Out:
# 현민유통김이사          949
# BM의류             547
# 마유리              520
# 비쥬앤              430
# 의류덤핑             394
# 개장수네형            205
# 행복이 보인다          201
# zkowm            179
# 토끼네땡몰            166
# 천안땡              156
# pacino666        154
# pastelguy        131
# 여성의류             109
# 실장                97
# 얍비                89
# 수원박실장             86
# 의류신발              82
# 더미 더미             81
# 국내 당일 주문 생산       80
# 테라유통              77
# kco0315           71
# 거누                68
# 대타홈런              65
# ggkkg             65
# 네오샵               64
# 도깨비이두표            63
# 나그네길              63
# 인지                63
# psd6734           62
# 일산의류도매            59
#                 ...
# 이지안                1
# S왕자                1
# 풀비엄마               1
# 쭈꾸                 1
# 초보 사업자             1
# 날고싶은 새             1
# 찬들이맘               1
# 친구들                1
# oufojl2            1
# 141                1
# QHBSMDavoibZT      1
# ghdqh01123         1
# 쇼룸다옴               1
# 신디양                1
# 음악은자세              1
# 나이스맨               1
# 늑대돌이               1
# 앗이건꼭사야해            1
# 매장24               1
# 소여니                1
# 중앙헌옷               1
# 통통건강               1
# 다싸                 1
# 지브리                1
# 돌멩군                1
# 운정지바겐              1
# GO                 1
# 샤라로랑               1
# jinsu0809          1
# 매력쟁이               1
# Name: user, Length: 829, dtype: int64

# %%
post_list['user'].value_counts().to_csv(os.getcwd() + "/" + "cafe_deaddodanggu_userlist" + ".csv", mode = 'w', header = True, encoding = 'utf-8-sig')

# %% [markdown]
# # 의류덤핑 / 300장 이하 팔아요

# %% [markdown]
# ### 일단 100개의 페이지에서 긁어오자

# %% [markdown]
# #### doctyppe html 밑의 부분은 아예보이질 않음 -> 스크롤을 안내린 문제 때문이었음

# %% [markdown]
# #html안에 html이 있는 형식으로 로컬의 iframe을 갖는 html을 긁어오기 위해서는 밑의 코드를 쳐줘야함
# #로컬에 iframe을 갖는 html파일을 만들고 아래와 같이 했더니 iframe안에 있는 html을 잘 읽어 옵니다.
# #by_name / by_tag_name도 된다 iframe안에 들어가 있는 소스 코드는 해당 형식의 코드를 작성해줘야함
# #이렇게 하지 않으면 iframe에 있는 코드를 불러오지 못함
# #따라서 소스코드가 제대로 불러지지 않는 것은 iframe여부를 확인하고 셀레늄으로 긁은 뒤html형식으로 바꿔야 한다

# %% [markdown]
# <img src="iframe_test.png">

# %%
browser.switch_to_frame(browser.find_element_by_name('cafe_main'))

# %%
body = browser.find_element_by_tag_name('body')

# %%
num_page_down = 1
while num_page_down:
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)
    num_page_down -= 1

# %%
browser.switch_to_frame(browser.find_element_by_name('cafe_main'))
#

# %%
#browser.find_element_by_css_selector('div.prev-next')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="9ad37a0f90444aaffed424563be403d6", element="0.46945684510707375-2")>

# %% [markdown]
# # 대도무역 크롤러

# %%
delay = 3
base_url = 'https://cafe.naver.com/deadodanggu'

# %%
browser = Chrome()
browser.maximize_window()
time.sleep(2)
browser.get(base_url)
browser.implicitly_wait(delay)

# %%
body = browser.find_element_by_tag_name('body')
num_page_down = 1
while num_page_down:
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(1)
    num_page_down -= 1

# %%
#제어 환경에 보여야 함
browser.find_elements_by_xpath('//*[@id = "group27"]/li[1]/a')[0].click()

# %%
dumping_data = pd.DataFrame({'post_title':[],
                           'owner':[],
                           'date':[],
                           'url':[]})
#ifrme to html 코드 굉장히 중요함
browser.switch_to_frame(browser.find_element_by_name('cafe_main'))
for i in range(1,11):
    a=i
    for j in range(1,12):#그래야 1~11까지의 범위가 됨
        try:
            if a==1:
                body = browser.find_element_by_tag_name('body')
                num_page_down = 1
                while num_page_down:
                    body.send_keys(Keys.PAGE_DOWN)
                    time.sleep(1)
                    num_page_down -= 1
                browser.find_elements_by_xpath('//*[@class = "prev-next"]/a['+ str(j) +']')[0].click()

                    
                html0 = browser.page_source    
                html= BeautifulSoup(html0,'html.parser')
                post0 = html.find_all('div',{'class':'article-board m-tcol-c'})[1]
                post1 = post0.find('tbody')
                
                post_title0 = post1.find_all('a',{'class':'article'})
                post_owner0 = post1.find_all('td',{'class':'p-nick'})
                post_date0 = post1.find_all('td',{'class':'td_date'})
                
                insert_data = pd.DataFrame({'post_title':[],
                                           'owner':[],
                                           'date':[],
                                           'url':[]})
                for post in range(len(post_title0)):
                    post_title = "".join(post_title0[post].text.split())
                    post_url = 'http://cafe.naver.com'+ post_title0[post]['href']
                    post_owner = post_owner0[post].find('a').text
                    post_date = post_date0[post].text
                    
                    insert_data2 =  pd.DataFrame({'post_title':[post_title],
                                           'owner':[post_owner],
                                           'date':[post_date],
                                           'url':[post_url]})
                    insert_data = insert_data.append(insert_data2)
                    
                dumping_data = dumping_data.append(insert_data)
                
            else:
                if j == 1:
                    pass
                else:
                    body = browser.find_element_by_tag_name('body')
                    num_page_down = 1
                    while num_page_down:
                        body.send_keys(Keys.PAGE_DOWN)
                        time.sleep(1)
                        num_page_down -= 1
                    browser.find_elements_by_xpath('//*[@class = "prev-next"]/a['+ str(j+1) +']')[0].click()

                
                html0 = browser.page_source    
                html= BeautifulSoup(html0,'html.parser')
                post0 = html.find_all('div',{'class':'article-board m-tcol-c'})[1]
                post1 = post0.find('tbody')
                
                post_title0 = post1.find_all('a',{'class':'article'})
                post_owner0 = post1.find_all('td',{'class':'p-nick'})
                post_date0 = post1.find_all('td',{'class':'td_date'})
                
                insert_data = pd.DataFrame({'post_title':[],
                                           'owner':[],
                                           'date':[],
                                           'url':[]})
                for post in range(len(post_title0)):
                    post_title = "".join(post_title0[post].text.split())
                    post_url = 'http://cafe.naver.com'+ post_title0[post]['href']
                    post_owner = post_owner0[post].find('a').text
                    post_date = post_date0[post].text
                    
                    insert_data2 =  pd.DataFrame({'post_title':[post_title],
                                           'owner':[post_owner],
                                           'date':[post_date],
                                           'url':[post_url]})
                    insert_data = insert_data.append(insert_data2)
                    
                dumping_data = dumping_data.append(insert_data)
        except:
            pass

# %%
dumping_data.index = range(len(dumping_data))

# %%
dumping_data
# Out:
#                                     post_title         owner         date  \
# 0                         어려운상황에서큰도움이되시고계십니다지금         zkowm        07:34
# 1                            봄:숙녀자켓2차(국산)판매합니다            김포        01:23
# 2                                  반팔셔츠급매합니다.~       서울제이스토리  2019.04.09.
# 3                                    여성속옷판매합니다       modus02  2019.04.09.
# 4       유명쇼핑몰,낱장도매가능여성의류빅사이즈55부터99까지보유중밴드매일업뎃중          로미스타  2019.04.09.
# 5                          new봄꽃나염자크티(국산)판매합니다            김포  2019.04.08.
# 6                 스트릿패션트레이닝,반팔,긴팔남방최저가공급해드립니다.            싸유  2019.04.08.
# 7                      유명브랜드와같은고퀄리티고급레깅스공급합니다.            싸유  2019.04.08.
# 8                 아동의류,성인의류해외수출및국내판매하실분들연락주세요.            내거  2019.04.08.
# 9                       (쇼핑몰재고)봄여름여성의류저가에판매합니다       modus02  2019.04.08.
# 10                                       가방땡쳐요  dbtjrwls4200  2019.04.08.
# 11        푸마골프티셔츠,클리브랜드여성골프바지덤핑정리합니다(가격제안받습니다)           덤핑왕  2019.04.07.
# 12                                  임부용바지판매합니다            내거  2019.04.06.
# 13                   C388-브랜드납품잔여분여성기능성티셔츠-5컬러          BM의류  2019.04.05.
# 14                               여성의류2.000장땡도매         드렁큰나비  2019.04.05.
# 15                         new봄꽃나염자크티(국산)판매합니다            김포  2019.04.04.
# 16                            광동생활건강강력탈취제덤핑입니다         DS아울렛  2019.04.04.
# 17                                봄여름용롱원피스판매해요          열혈셀러  2019.04.04.
# 18                        ●new봄숙녀롱티셔츠(국산)판매합니다            김포  2019.04.03.
# 19                                   여성속옷판매합니다       modus02  2019.04.03.
# 20                     유명브랜드와같은고퀄리티고급레깅스공급합니다.            싸유  2019.04.03.
# 21                          간절기여성의류땡도매장당1.200원         드렁큰나비  2019.04.03.
# 22                                속옷매장정리분판매합니다       modus02  2019.04.03.
# 23                     유명브랜드와같은고퀄리티고급레깅스공급합니다.            싸유  2019.04.02.
# 24                               여성브랜드코튼니트4종세트           비쥬앤  2019.04.02.
# 25       [추가입고]동대문도매상가의류(여성의류2만장,아동복1만장)100%국산         엠제이무역  2019.04.02.
# 26                         봄2숙녀남방브라우스(국산)판매합니다            김포  2019.04.01.
# 27                                여성레깅스바지판매합니다            내거  2019.04.01.
# 28                    홈쇼핑미시여성3종티셔츠100장1500원땡처리            얍비  2019.04.01.
# 29                아동복브랜드공장물건3150여장1600원덤핑출고합니다          테라유통  2019.04.01.
# ...                                        ...           ...          ...
# 1620                      zz655목폴라니트원피스_1,500원       현민유통김이사  2018.03.19.
# 1621                         zz804아동반바지_1,200원       현민유통김이사  2018.03.19.
# 1622         zz757영문후드티셔츠(피치기모)_1,500원_S,XS사이즈       현민유통김이사  2018.03.19.
# 1623                      zz753라셀포인트가디건_1,000원       현민유통김이사  2018.03.19.
# 1624               푸마골프티셔츠,클리브랜드여성골프바지덤핑정리합니다.          오리오리  2018.03.19.
# 1625              zz945여성캐주얼티셔츠mix_50장장당1,500원       현민유통김이사  2018.03.17.
# 1626                  zz946니트원피스mix50장장당1,800원       현민유통김이사  2018.03.17.
# 1627                           zz654니트가디건_800원       현민유통김이사  2018.03.17.
# 1628                      zz749남성반폴라티셔츠_1,000원       현민유통김이사  2018.03.16.
# 1629                       zz738니트2종mix_1,500원       현민유통김이사  2018.03.16.
# 1630                        zz808목폴라니트티_1,500원       현민유통김이사  2018.03.16.
# 1631                          zz781티셔츠mix_800원       현민유통김이사  2018.03.16.
# 1632                                   휠라맨투맨판매          의류덤핑  2018.03.16.
# 1633             시즌off여성의류폭탄세일이벤트전품목1000~2000원         엠제이무역  2018.03.15.
# 1634  앞도바,노점에서도인기좋습니다~한분이서5000원10000원씩갖고가시네요^^            실장  2018.03.15.
# 1635                                벌써부터움직입니다!            실장  2018.03.15.
# 1636        지금부터시작입니다~~~바빠지기시작했습니다!브랜드라잘빠지네요^^            실장  2018.03.15.
# 1637           4-50만원갖고시작해서하루20만원가까이버시면괘찮지않나요?            실장  2018.03.15.
# 1638                    zz944남성배색남방50장장당2,000원       현민유통김이사  2018.03.15.
# 1639                    zz944남성배색남방50장장당2,000원        인디에이맨즈  2018.03.26.
# 1640                      무신사입점디자이너브랜드여성용남방80장          프리소울  2018.03.15.
# 1641                     zz943남성심플남방_50장2,000원       현민유통김이사  2018.03.15.
# 1642                     zz943남성심플남방_50장2,000원        인디에이맨즈  2018.03.26.
# 1643                 zz942여성용비치반바지2종_50장1,500원       현민유통김이사  2018.03.15.
# 1644                       zz779남성니트랜덤mix_800원       현민유통김이사  2018.03.15.
# 1645                        zz778아동니트바지_1,200원       현민유통김이사  2018.03.15.
# 1646                         zz807니트mix_1,000원       현민유통김이사  2018.03.15.
# 1647                        최고급남녀남방땡처리선착순1800원           블루웰  2018.03.14.
# 1648                        zz806반바지2종mix_800원       현민유통김이사  2018.03.14.
# 1649                      zz660구제핏데님숏자켓_1,500원       현민유통김이사  2018.03.14.
#
#                                                     url
# 0     http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1     http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 2     http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 3     http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 4     http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 5     http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 6     http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 7     http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 8     http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 9     http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 10    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 11    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 12    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 13    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 14    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 15    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 16    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 17    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 18    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 19    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 20    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 21    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 22    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 23    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 24    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 25    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 26    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 27    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 28    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 29    http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# ...                                                 ...
# 1620  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1621  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1622  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1623  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1624  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1625  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1626  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1627  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1628  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1629  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1630  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1631  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1632  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1633  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1634  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1635  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1636  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1637  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1638  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1639  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1640  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1641  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1642  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1643  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1644  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1645  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1646  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1647  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1648  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
# 1649  http://cafe.naver.com/ArticleRead.nhn?clubid=1...
#
# [1650 rows x 4 columns]

# %%
dumping_data['url'].iloc[0]
# Out:
# 'http://cafe.naver.com/ArticleRead.nhn?clubid=18238966&page=1&menuid=34&boardtype=L&articleid=33217&referrerAllArticles=false'

# %% [markdown]
# # practice

# %%
browser.find_elements_by_xpath('//*[@class = "prev-next"]/a['+ str(4) +']')[0].click()

# %%
#ifrme to html 코드 굉장히 중요함
browser.switch_to_frame(browser.find_element_by_name('cafe_main'))
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-50-61b11e33aafb> in <module>()
#       1 #ifrme to html 코드 굉장히 중요함
# ----> 2 browser.switch_to_frame(browser.find_element_by_name('cafe_main'))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_name(self, name)
#     493             element = driver.find_element_by_name('foo')
#     494         """
# --> 495         return self.find_element(by=By.NAME, value=name)
#     496
#     497     def find_elements_by_name(self, name):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     964         return self.execute(Command.FIND_ELEMENT, {
#     965             'using': by,
# --> 966             'value': value})['value']
#     967
#     968     def find_elements(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     318         response = self.command_executor.execute(driver_command, params)
#     319         if response:
# --> 320             self.error_handler.check_response(response)
#     321             response['value'] = self._unwrap_value(
#     322                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"name","selector":"cafe_main"}
#   (Session info: chrome=73.0.3683.86)
#   (Driver info: chromedriver=2.38.552522 (437e6fbedfa8762dec75e2c5b3ddb86763dc9dcb),platform=Windows NT 10.0.17134 x86_64)

# %%
html0 = browser.page_source

# %%
html= BeautifulSoup(html0,'html.parser')

# %%
post0 = html.find_all('div',{'class':'article-board m-tcol-c'})[1]

# %%
post0
# Out:
# <div class="article-board m-tcol-c">
# <table>
# <caption><span class="blind">게시물 목록</span></caption>
# <colgroup>
# <col style="width:88px;"/>
# <col/>
# <col style="width:118px"/>
# <col style="width:80px"/>
# <col style="width:68px"/>
# <col style="width:68px"/>
# </colgroup>
# <tbody>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32745</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32745&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     아동 상하 실내복 1250세트 2200원 땡처리합니다.
#
#
#                             </a>
# <span class="list-i-img"><i class="blind">사진</i></span>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'gbaker',3,'테라유통','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">테라유통</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_gbaker_0"));</script>
# </td>
# <td class="td_date">2019.03.26.</td>
# <td class="td_view">18</td>
# <td class="td_likes">1</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32742</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32742&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     원피스 준비하세요
#
#
#                             </a>
# <span class="list-i-img"><i class="blind">사진</i></span>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'vyeodnjs',3,'열혈셀러','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">열혈셀러</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_vyeodnjs_1"));</script>
# </td>
# <td class="td_date">2019.03.26.</td>
# <td class="td_view">15</td>
# <td class="td_likes">0</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32739</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32739&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     아동양말/도널드후드티
#
#
#                             </a>
# <span class="list-i-img"><i class="blind">사진</i></span>
# <a class="cmt" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32739&amp;referrerAllArticles=false&amp;commentFocus=true" onclick="clickcr(this, 'gnr.cmt','','',event);">
#                                     [<em>1</em>]
#                                 </a>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'zzz091015',3,'울빵이맘','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">울빵이맘</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_zzz091015_2"));</script>
# </td>
# <td class="td_date">2019.03.26.</td>
# <td class="td_view">15</td>
# <td class="td_likes">0</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32721</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32721&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     26수 무지 반팔티 입니다.
#
#
#                             </a>
# <span class="list-i-img"><i class="blind">사진</i></span>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'pastelguy',3,'pastelguy','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">pastelguy</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_pastelguy_3"));</script>
# </td>
# <td class="td_date">2019.03.25.</td>
# <td class="td_view">23</td>
# <td class="td_likes">1</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32720</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32720&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     ● new 봄 아방뜨 bi / 네이비,블랙 (국산)
#
#
#                             </a>
# <span class="list-i-img"><i class="blind">사진</i></span>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'wgh9076',3,'김포','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">김포</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_wgh9076_4"));</script>
# </td>
# <td class="td_date">2019.03.25.</td>
# <td class="td_view">9</td>
# <td class="td_likes">0</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32713</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32713&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     아동 상하 실내복 1250세트 2200원
#
#
#                             </a>
# <span class="list-i-img"><i class="blind">사진</i></span>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'gbaker',3,'테라유통','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">테라유통</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_gbaker_5"));</script>
# </td>
# <td class="td_date">2019.03.25.</td>
# <td class="td_view">16</td>
# <td class="td_likes">1</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32709</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32709&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     아동복,성인복,해외수출및 국내 판매 하실분들 연락 주세요.
#
#
#                             </a>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'a828288',3,'내거','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">내거</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_a828288_6"));</script>
# </td>
# <td class="td_date">2019.03.25.</td>
# <td class="td_view">10</td>
# <td class="td_likes">0</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32696</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32696&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     여성보정속옷 판매합니다
#
#
#                             </a>
# <span class="list-i-img"><i class="blind">사진</i></span>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'modus02',3,'modus02','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">modus02</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_modus02_7"));</script>
# </td>
# <td class="td_date">2019.03.25.</td>
# <td class="td_view">10</td>
# <td class="td_likes">0</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32686</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32686&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     헹거 1-2개만 깔아보세요~~ 매출이 장난 아닙니다 지금
#
#
#                             </a>
# <span class="list-i-img"><i class="blind">사진</i></span>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'pamadeux',3,'zkowm','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">zkowm</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_pamadeux_8"));</script>
# </td>
# <td class="td_date">2019.03.24.</td>
# <td class="td_view">32</td>
# <td class="td_likes">0</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32675</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32675&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     봄옷 준비하세요(새상품)
#
#
#                             </a>
# <span class="list-i-img"><i class="blind">사진</i></span>
# <a class="cmt" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32675&amp;referrerAllArticles=false&amp;commentFocus=true" onclick="clickcr(this, 'gnr.cmt','','',event);">
#                                     [<em>2</em>]
#                                 </a>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'vyeodnjs',3,'열혈셀러','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">열혈셀러</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_vyeodnjs_9"));</script>
# </td>
# <td class="td_date">2019.03.24.</td>
# <td class="td_view">41</td>
# <td class="td_likes">0</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32673</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32673&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     스포츠레깅스입니다
#
#
#                             </a>
# <span class="list-i-img"><i class="blind">사진</i></span>
# <a class="cmt" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32673&amp;referrerAllArticles=false&amp;commentFocus=true" onclick="clickcr(this, 'gnr.cmt','','',event);">
#                                     [<em>1</em>]
#                                 </a>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'pastelguy',3,'pastelguy','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">pastelguy</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_pastelguy_10"));</script>
# </td>
# <td class="td_date">2019.03.23.</td>
# <td class="td_view">37</td>
# <td class="td_likes">0</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32662</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32662&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     여름 7부청바지,면반바지
#
#
#                             </a>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'modus02',3,'modus02','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">modus02</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_modus02_11"));</script>
# </td>
# <td class="td_date">2019.03.22.</td>
# <td class="td_view">19</td>
# <td class="td_likes">0</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32656</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32656&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     국내생산 동대문 긴팔티 3000원씩 판매합니다.
#
#
#                             </a>
# <span class="list-i-img"><i class="blind">사진</i></span>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'dkrak11111',3,'0박하사탕0','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">0박하사탕0</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_dkrak11111_12"));</script>
# </td>
# <td class="td_date">2019.03.22.</td>
# <td class="td_view">25</td>
# <td class="td_likes">0</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32638</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32638&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     남여공용 후드티 1600장 완사 판매합니다.
#
#
#                             </a>
# <span class="list-i-img"><i class="blind">사진</i></span>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'shc7586',3,'싸가지 서대리','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">싸가지 서대리</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_shc7586_13"));</script>
# </td>
# <td class="td_date">2019.03.21.</td>
# <td class="td_view">39</td>
# <td class="td_likes">0</td>
# </tr>
# <tr>
# <td class="td_article" colspan="2">
# <div class="board-number"><div class="inner_number">32626</div></div>
# <div class="board-list">
# <div class="inner_list">
# <a class="article" href="/ArticleRead.nhn?clubid=18238966&amp;page=4&amp;menuid=34&amp;boardtype=L&amp;articleid=32626&amp;referrerAllArticles=false" onclick="clickcr(this, 'gnr.title','','',event);">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     각종 ss 여성의류 덤핑 목록
#
#
#                             </a>
# <span class="list-i-img"><i class="blind">사진</i></span>
# </div>
# </div>
# </td>
# <td class="td_name">
# <div class="pers_nick_area"><table cellspacing="0" role="presentation"><tbody><tr><td class="p-nick"><a class="m-tcol-c" href="#" onclick="ui(event, 'say201231',3,'인천도매덤핑','18238966','', 'false', 'true', 'deadodanggu', 'false', '34'); return false;">인천도매덤핑</a><span class="mem-level"><img height="11" src="https://cafe.pstatic.net/levelicon/1/1_110.gif" width="11"/></span></td></tr></tbody></table></div><script type="text/javascript">wordBreak($("article_say201231_14"));</script>
# </td>
# <td class="td_date">2019.03.21.</td>
# <td class="td_view">25</td>
# <td class="td_likes">0</td>
# </tr>
# </tbody>
# </table>
# </div>

# %%
post1 = post0.find('tbody')

# %%
post_title0 = post1.find_all('a',{'class':'article'})

# %%
post_title = "".join(post_title0[0].text.split())

# %%
post_title
# Out:
# '홈쇼핑미시여성3종티셔츠100장1500원땡처리'

# %%
post_owner0 = post1.find_all('td',{'class':'p-nick'})

# %%
post_owner = post_owner0[3].find('a').text
# Out:
# '열혈셀러'

# %%
post_date0 = post1.find_all('td',{'class':'td_date'})

# %%
post_date0[14].text
# Out:
# '2019.03.26.'

# %% [markdown]
# # 게시물 본문 긁어오기

# %% [markdown]
# ### img와 text를 따로긁어서 보여주면 됨

# %%
base_url2 = 'http://cafe.naver.com'+post_title0[0]['href']

# %%
base_url2 = dumping_data['url'].iloc[0]

# %%
browser = Chrome()
browser.maximize_window()
time.sleep(2)
browser.get(base_url2)
browser.implicitly_wait(delay)
#새창을 켜게 된다면 로그인을 새로해야 하는데 네이버 측에서 자동 제어 로그인을 막아놨기 때문에
#먼저 로그인을 한 후 진행해야 함

# %%
browser.get(base_url2)
browser.implicitly_wait(delay)

# %%
browser.switch_to_frame(browser.find_element_by_name('cafe_main'))

# %%
html_all0 = browser.page_source

# %%
html_all = BeautifulSoup(html_all0,'html.parser')

# %%
html_all.find('div',{'class':'tbody m-tcol-c'}).find_all('img')[0]['src']
# Out:
# 'https://cafeptthumb-phinf.pstatic.net/MjAxOTAzMjRfMTgg/MDAxNTUzNDE2ODgzMTY0.-ZXKa-08dbfQzF9NDv8wJKI6_jdNpkEXjNNeIV8ANWYg.cZ7r3MKIyro8AmR9FG9he69PrGo7Jb_H4rpUZ3y_558g.JPEG.pamadeux/KakaoTalk_20190322_131034857.jpg?type=w740'

# %% [markdown]
# #### get_text() method는 하위 태그에 있는 모든 텍스트를 긁어오는 것
# #### 만일 사진을 제외하고 설명만을 긁어온다면 이렇게 긁어와도 무방

# %%
post_text = str(html_all.find('div',{'class':'tbody m-tcol-c'}).get_text())

# %%
str(html_all.find('div',{'class':'tbody m-tcol-c'}).get_text())
# Out:
# '\n요즘 없어서 못파는 마약원단 시리즈!피치입니다!브랜드 없는 상품도 잘 나가는데\xa0거기다가 유명브랜드를 달으니 판매량↑\xa0 더 좋습니다^^대충 만든 것이 아닌 착용 했을때 핏과 싸이즈도 편안하게 만들어서금상첨화!!\xa0인기절정 짱구무뉘를 포함해서인기원단 7가지를 더해서 총 9가지쌈지브랜드로 최저가로 드리니 반응 좋습니다 지금수량 부담없이 편안하게 시작하세요^^주로 실내에서 입는 상품이라\xa0쭉~~~~ 나갑니다!▲주머니 및 시보리형 고급 바지시리즈\xa0기본 2,900원\xa0마대 2,700원(1마대 9가지 디자인 20장씩 합 180장)위 상품외퀼트 발매트,베개피 등\xa0 각종 퀼트만빵 이불,패드5000빵 초대박 7족 양말 셋트2019 봄 신상 의류 등새로운 상품도 지속적으로 입고 되구 있습니다^^창고 및 사무실공덕역 4번출구앞서울시 마포구 공덕동 234-15호선, 6호선, 공항철도가 교차하는공덕역 4번출구 앞에 있습니다.혼잡하지 않구요...주차장 완비되어 있습니다^^☎02-2636-8746☎010-5431-2013오시기 힘드신 지방 분들이나 해외 분들 믿고 주문하세요...그 동안의 장사 경험을 바탕으로 잘 맞춰 보내드리고 있습니다.지방 택배및 해외택배 가능합니다.5시-6시까지 주문시 당일택배 출고 가능합니다.\n'

# %%
#이러한 식으로 내용만 전체 긁어올 수 있음 하지만 이렇게 된다면 굉장히 줄글로만 보이기 때문에 
#그렇지만 줄글로 가져오면 안될 것 같음..
"".join(re.findall('[가-힣0-9]',str(html_all.find('div',{'class':'tbody m-tcol-c'}).get_text())))
# Out:
# '요즘없어서못파는마약원단시리즈피치입니다브랜드없는상품도잘나가는데거기다가유명브랜드를달으니판매량더좋습니다대충만든것이아닌착용했을때핏과싸이즈도편안하게만들어서금상첨화인기절정짱구무뉘를포함해서인기원단7가지를더해서총9가지쌈지브랜드로최저가로드리니반응좋습니다지금수량부담없이편안하게시작하세요주로실내에서입는상품이라쭉나갑니다주머니및시보리형고급바지시리즈기본2900원마대2700원1마대9가지디자인20장씩합180장위상품외퀼트발매트베개피등각종퀼트만빵이불패드5000빵초대박7족양말셋트2019봄신상의류등새로운상품도지속적으로입고되구있습니다창고및사무실공덕역4번출구앞서울시마포구공덕동23415호선6호선공항철도가교차하는공덕역4번출구앞에있습니다혼잡하지않구요주차장완비되어있습니다022636874601054312013오시기힘드신지방분들이나해외분들믿고주문하세요그동안의장사경험을바탕으로잘맞춰보내드리고있습니다지방택배및해외택배가능합니다5시6시까지주문시당일택배출고가능합니다'

# %%
'img' in str(html_all.find('div',{'class':'tbody m-tcol-c'}))
# Out:
# True

# %%
post_img = html_all.find('div',{'class':'tbody m-tcol-c'}).find_all('img')

# %%
post_img[0]['src']
# Out:
# 'https://cafeptthumb-phinf.pstatic.net/MjAxOTAzMjRfMTgg/MDAxNTUzNDE2ODgzMTY0.-ZXKa-08dbfQzF9NDv8wJKI6_jdNpkEXjNNeIV8ANWYg.cZ7r3MKIyro8AmR9FG9he69PrGo7Jb_H4rpUZ3y_558g.JPEG.pamadeux/KakaoTalk_20190322_131034857.jpg?type=w740'

# %%
post_text = str(html_all.find('div',{'class':'tbody m-tcol-c'}).get_text())

# %%
#src를 어떻게 코드상에 최적화 시킬지
for i in range(len(post_img)):
    img_0 = post_img[i]['src']
    img_source = '\n <img src = ' + img_0 + '>'
    post_text = post_text + img_source

# %%
for i in range(len(post_img)):
    img_0 = post_img[i]['src']
    img_source =  img_0 
    post_text = post_text + img_source

# %%
post_text
# Out:
# '\n요즘 없어서 못파는 마약원단 시리즈!피치입니다!브랜드 없는 상품도 잘 나가는데\xa0거기다가 유명브랜드를 달으니 판매량↑\xa0 더 좋습니다^^대충 만든 것이 아닌 착용 했을때 핏과 싸이즈도 편안하게 만들어서금상첨화!!\xa0인기절정 짱구무뉘를 포함해서인기원단 7가지를 더해서 총 9가지쌈지브랜드로 최저가로 드리니 반응 좋습니다 지금수량 부담없이 편안하게 시작하세요^^주로 실내에서 입는 상품이라\xa0쭉~~~~ 나갑니다!▲주머니 및 시보리형 고급 바지시리즈\xa0기본 2,900원\xa0마대 2,700원(1마대 9가지 디자인 20장씩 합 180장)위 상품외퀼트 발매트,베개피 등\xa0 각종 퀼트만빵 이불,패드5000빵 초대박 7족 양말 셋트2019 봄 신상 의류 등새로운 상품도 지속적으로 입고 되구 있습니다^^창고 및 사무실공덕역 4번출구앞서울시 마포구 공덕동 234-15호선, 6호선, 공항철도가 교차하는공덕역 4번출구 앞에 있습니다.혼잡하지 않구요...주차장 완비되어 있습니다^^☎02-2636-8746☎010-5431-2013오시기 힘드신 지방 분들이나 해외 분들 믿고 주문하세요...그 동안의 장사 경험을 바탕으로 잘 맞춰 보내드리고 있습니다.지방 택배및 해외택배 가능합니다.5시-6시까지 주문시 당일택배 출고 가능합니다.\nhttps://cafeptthumb-phinf.pstatic.net/MjAxOTAzMjRfMTgg/MDAxNTUzNDE2ODgzMTY0.-ZXKa-08dbfQzF9NDv8wJKI6_jdNpkEXjNNeIV8ANWYg.cZ7r3MKIyro8AmR9FG9he69PrGo7Jb_H4rpUZ3y_558g.JPEG.pamadeux/KakaoTalk_20190322_131034857.jpg?type=w740https://cafeptthumb-phinf.pstatic.net/MjAxOTAzMjRfMjY2/MDAxNTUzNDE2ODgzODk4.fGdBmWEQJ4913w4NLt7tM7AJYO_aR4pBdjtEgWO5ihUg.Zm9RoLz3YCp0JEqRAcb_J4RVNDcucnzEyr7bsibn-c8g.PNG.pamadeux/ErBvSLfUk1Ux15Yin8klCfK7POLa.png?type=w740'

# %% [markdown]
# #### 본문내용 텍스트를 그대로 긁어오기

# %%
div_test = html_all.find('div',{'class':'tbody m-tcol-c'}).find('div',{'style':'font-family: dotum;'}).find('div',{'style':'font-family: dotum;'})

# %%
'img' in str(div_test.find_all('div',{'class':'NHN_Writeform_Main'})[42])
# Out:
# True

# %%
div_test.find_all('div',{'class':'NHN_Writeform_Main'})[42].find('img')['src']
# Out:
# 'https://cafeptthumb-phinf.pstatic.net/MjAxOTAzMjRfMTgg/MDAxNTUzNDE2ODgzMTY0.-ZXKa-08dbfQzF9NDv8wJKI6_jdNpkEXjNNeIV8ANWYg.cZ7r3MKIyro8AmR9FG9he69PrGo7Jb_H4rpUZ3y_558g.JPEG.pamadeux/KakaoTalk_20190322_131034857.jpg?type=w740'
